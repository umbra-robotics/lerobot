# %% [markdown]
# # SO-100 Teleoperation
# Run cells top to bottom. Ports and cameras are auto-detected so it works regardless of USB enumeration order.

# %% [markdown]
# ## 1. Detect Ports & Cameras
# Scans all `/dev/ttyACM*` and `/dev/ttyUSB*` ports, reads motor voltage to identify leader (~5V USB) vs follower (~12V PSU).
# Reads `/sys/class/video4linux/` to identify wrist (Innomaker) and top (other USB) cameras, ignoring the laptop webcam.

# %%
import glob
import time
import scservo_sdk as scs
from pathlib import Path

# ── Motor port detection ─────────────────────────────────────────────
VOLTAGE_ADDR = 62  # Present_Voltage, 1 byte, unit = 0.1V

# Find all serial ports dynamically
ports = sorted(glob.glob("/dev/ttyACM*") + glob.glob("/dev/ttyUSB*"))
if not ports:
    print("✗ No serial ports found! Are the arms plugged in?")

leader_port = None
follower_port = None

for port_path in ports:
    port = scs.PortHandler(port_path)
    if not port.openPort():
        print(f"  {port_path}: CANNOT OPEN")
        continue
    port.setBaudRate(1000000)
    time.sleep(0.1)
    ph = scs.PacketHandler(0)

    # Retry up to 3 times (first read can be flaky)
    for _attempt in range(3):
        data, comm, _ = ph.readTxRx(port, 1, VOLTAGE_ADDR, 1)
        if comm == 0:
            break
        time.sleep(0.1)

    port.closePort()

    if comm != 0:
        # Not a motor controller on this port
        continue

    volts = data[0] / 10.0
    if volts > 6.5:
        label = "FOLLOWER (~8V)"
        follower_port = port_path
    else:
        label = "LEADER  (~5V)"
        leader_port = port_path

    print(f"  {port_path}: {volts:.1f}V  →  {label}")

if leader_port and follower_port:
    print("✓ Ports detected OK!")
else:
    print("✗ ERROR: Could not find both arms! Are they plugged in?")

# ── Camera detection ─────────────────────────────────────────────────
# Patterns to IGNORE (laptop integrated cameras)
IGNORE_PATTERNS = ["webcam", "integrated", "laptop"]
# Pattern for the Innomaker wrist camera
WRIST_PATTERN = "innomaker"

wrist_cam_index = None
top_cam_index = None
seen_names = set()

print()
sysfs = Path("/sys/class/video4linux")
for dev in sorted(sysfs.iterdir(), key=lambda d: d.name):
    name_file = dev / "name"
    if not name_file.exists():
        continue

    cam_name = name_file.read_text().strip()

    # Skip duplicate entries (each physical camera creates 2 /dev/video* nodes)
    if cam_name in seen_names:
        continue
    seen_names.add(cam_name)

    # Extract the integer index from e.g. "video2"
    idx = int(dev.name.replace("video", ""))
    name_lower = cam_name.lower()

    # Skip laptop / integrated cameras
    if any(p in name_lower for p in IGNORE_PATTERNS):
        print(f"  video{idx}: {cam_name}  →  SKIP (laptop)")
        continue

    # Classify
    if WRIST_PATTERN in name_lower:
        wrist_cam_index = idx
        print(f"  video{idx}: {cam_name}  →  WRIST")
    elif top_cam_index is None:
        top_cam_index = idx
        print(f"  video{idx}: {cam_name}  →  TOP")
    else:
        print(f"  video{idx}: {cam_name}  →  SKIP (extra)")

if wrist_cam_index is not None and top_cam_index is not None:
    print("✓ Both cameras detected!")
elif wrist_cam_index is not None:
    print("✓ Wrist camera detected (no top camera)")
elif top_cam_index is not None:
    print("✓ Top camera detected (no wrist camera)")
else:
    print("⚠ No cameras detected")
# Out:
#   /dev/ttyACM0: 5.2V  →  LEADER  (~5V)
#   /dev/ttyACM1: 8.2V  →  FOLLOWER (~8V)
# ✓ Ports detected OK!
#
#   video0: USB Camera: ProXtend  →  TOP
#   video2: Innomaker-U20CAM-1080p-S1: Inno  →  WRIST
#   video4: HD WebCam: HD WebCam  →  SKIP (laptop)
# ✓ Both cameras detected!

# %% [markdown]
# ## 2. Choose Mode and Run

# %%
# Auto-select mode based on detected cameras (override below if needed)
if wrist_cam_index is not None and top_cam_index is not None:
    MODE = "top_wrist"
elif wrist_cam_index is not None:
    MODE = "wrist_only"
elif top_cam_index is not None:
    MODE = "top_only"
else:
    MODE = "basic"

# Manual override — uncomment ONE to force a mode:
#MODE = "basic"
#MODE = "wrist_only"
#MODE = "top_only"
#MODE = "top_wrist"

# Build camera CLI flags from detected indices
cam_parts = []
if MODE in ("top_only", "top_wrist") and top_cam_index is not None:
    cam_parts.append(f"top: {{type: opencv, index_or_path: {top_cam_index}, width: 640, height: 480, fps: 30}}")
if MODE in ("wrist_only", "top_wrist") and wrist_cam_index is not None:
    cam_parts.append(f"wrist: {{type: opencv, index_or_path: {wrist_cam_index}, width: 640, height: 480, fps: 30}}")

if cam_parts:
    camera_flag = f"--robot.cameras='{{ {', '.join(cam_parts)} }}' --display_data=true"
else:
    camera_flag = ""

assert leader_port and follower_port, "Run cell 1 first! Ports not detected."

cmd = (
    f"lerobot-teleoperate"
    f" --robot.type=so100_follower --robot.port={follower_port} --robot.id=my_follower"
    f" --teleop.type=so100_leader --teleop.port={leader_port} --teleop.id=my_leader"
    f" {camera_flag}"
)

print(f"Mode: {MODE}")
if top_cam_index is not None:
    print(f"  top   → video{top_cam_index}")
if wrist_cam_index is not None:
    print(f"  wrist → video{wrist_cam_index}")
print(f"\nCommand:\n\n{cmd}\n")
# Out:
# Mode: top_wrist
#   top   → video0
#   wrist → video2
#
# Command:
#
# lerobot-teleoperate --robot.type=so100_follower --robot.port=/dev/ttyACM0 --robot.id=my_follower --teleop.type=so100_leader --teleop.port=/dev/ttyACM1 --teleop.id=my_leader --robot.cameras='{ top: {type: opencv, index_or_path: 0, width: 640, height: 480, fps: 30}, wrist: {type: opencv, index_or_path: 2, width: 640, height: 480, fps: 30} }' --display_data=true

# %%
# Run teleoperation (Ctrl+C or interrupt kernel to stop)
import subprocess, shlex, sys

print("Starting teleoperation... (interrupt kernel to stop)\n")
process = subprocess.Popen(shlex.split(cmd), stdout=sys.stdout, stderr=sys.stderr)
process.wait()

# %% [markdown]
# ## 3. Record Episodes
# Uses `lerobot-record` with the same auto-detected ports and cameras. Set your dataset name and task description below.

# %%
# ── Recording settings ────────────────────────────────────────────────
REPO_ID = "umbra-robotics/so100_pick_cube"   # HuggingFace dataset repo
TASK = "Pick up the cube and place it in the bin"
NUM_EPISODES = 1
EPISODE_TIME_S = 60     # max seconds per episode
RESET_TIME_S = 10       # seconds between episodes to reset the scene
FPS = 30
PUSH_TO_HUB = False     # set True to upload to HuggingFace Hub

assert leader_port and follower_port, "Run cell 1 first! Ports not detected."

record_cmd = (
    f"lerobot-record"
    f" --robot.type=so100_follower --robot.port={follower_port} --robot.id=my_follower"
    f" --teleop.type=so100_leader --teleop.port={leader_port} --teleop.id=my_leader"
    f" {camera_flag}"
    f" --dataset.repo_id={REPO_ID}"
    f" --dataset.single_task='{TASK}'"
    f" --dataset.num_episodes={NUM_EPISODES}"
    f" --dataset.episode_time_s={EPISODE_TIME_S}"
    f" --dataset.reset_time_s={RESET_TIME_S}"
    f" --dataset.fps={FPS}"
    f" --dataset.push_to_hub={str(PUSH_TO_HUB).lower()}"
)

print(f"Recording {NUM_EPISODES} episode(s) → {REPO_ID}")
print(f"Task: {TASK}")
print(f"Episode: {EPISODE_TIME_S}s, reset: {RESET_TIME_S}s, fps: {FPS}")
print(f"\nCommand:\n\n{record_cmd}\n")

# %%
# Run recording (interrupt kernel to stop)
import subprocess, shlex, sys

print("Starting recording... (interrupt kernel to stop)\n")
process = subprocess.Popen(shlex.split(record_cmd), stdout=sys.stdout, stderr=sys.stderr)
process.wait()

# %% [markdown]
# ## 4. Train π₀.₅ Policy with LoRA
#
# Finetunes `lerobot/pi05_base` using LoRA adapters (~20M trainable params vs 3.6B full). Much faster, tiny checkpoints, fits easily on GB10 unified memory — previous full-finetune smoke crashed at checkpoint save because the 3.6B optimizer state exhausted the shared CPU/GPU pool.
#
# Prereqs:
# - `uv sync --extra pi --extra peft --extra dev`
# - Base model at `./models/pi05_base` (`hf download lerobot/pi05_base --local-dir ./models/pi05_base`)
# - Dataset at `./data/<repo_id>` (`hf download <repo_id> --repo-type dataset --local-dir ./data/<repo_id>`)
#
# **Recipe**: PI reference — lr=2.5e-5, AdamW β=(0.9,0.95), cosine decay, bf16. LoRA rank=16 on pi05's default target modules (gemma_expert self-attention q/v + action projections). Vision tower and language model stay frozen.
#
# Run **4a** (smoke, a few minutes) to verify the pipeline, then **4b** (full run).

# %%
# ── Shared training settings ──────────────────────────────────
# Smoke and full runs use IDENTICAL flags — only steps/save/log differ.
DATASET_REPO_ID = "ChrisCrossAppleSauce/so100_plant_pencil"
DATASET_ROOT    = "./data/so100_plant_pencil"
PRETRAINED_PATH = "./models/pi05_base"
OUTPUT_REPO_ID  = "ChrisCrossAppleSauce/pi05_so100_plant_pencil"
BATCH_SIZE      = 32
SEED            = 42
LORA_RANK       = 16

# Policy flags (PI reference recipe + LoRA + torch.compile)
# gradient_checkpointing=false: LoRA already shrinks optimizer state ~1800x (29GB → 16MB),
# and keeping it on triggers an Inductor bug in the rematerialization partitioner on GB10
# (KeyError('_scaled_dot_product_flash_attention')). Off is both safer and faster here.
POLICY_FLAGS = (
    f" --policy.type=pi05"
    f" --policy.pretrained_path={PRETRAINED_PATH}"
    f" --policy.repo_id={OUTPUT_REPO_ID}"
    f" --policy.device=cuda"
    f" --policy.dtype=bfloat16"
    f" --policy.compile_model=true"
    f" --policy.compile_mode=reduce-overhead"   # GB10 has too few SMs for max-autotune
    f" --policy.gradient_checkpointing=false"
    f" --policy.freeze_vision_encoder=false"   # LoRA targets the gemma_expert, not the vision tower
    f" --policy.train_expert_only=false"
)

# LoRA adapter — pi05 provides the target_modules regex by default
# (gemma_expert self-attention q/v + action projections). We only set method
# and rank; lora_alpha/dropout fall back to peft's LoraConfig defaults.
PEFT_FLAGS = (
    f" --peft.method_type=LORA"
    f" --peft.r={LORA_RANK}"
)

DATASET_FLAGS = (
    f" --dataset.repo_id={DATASET_REPO_ID}"
    f" --dataset.root={DATASET_ROOT}"
)

WANDB_PROJECT = "pi05_so100_plant_pencil"

COMMON_FLAGS = (
    f" --batch_size={BATCH_SIZE}"
    f" --seed={SEED}"
    f" --eval_freq=0"
    f" --wandb.enable=true"
    f" --wandb.project={WANDB_PROJECT}"
)

print("Settings loaded.")
print(f"Dataset: {DATASET_REPO_ID}  (local: {DATASET_ROOT})")
print(f"Base:    {PRETRAINED_PATH}")
print(f"Batch:   {BATCH_SIZE}  |  seed: {SEED}  |  LoRA rank: {LORA_RANK}")
# Out:
# Settings loaded.
# Dataset: ChrisCrossAppleSauce/so100_plant_pencil  (local: ./data/so100_plant_pencil)
# Base:    ./models/pi05_base
# Batch:   32  |  seed: 42  |  LoRA rank: 16

# %%
# ── 4a. Smoke test command ─────────────────────────────────
# Same flags as 4b, just shorter — validates the full-run config end-to-end.
from pathlib import Path
SMOKE_OUTPUT_DIR = "./outputs/pi05_smoke"
SMOKE_STEPS      = 10
SMOKE_SAVE_FREQ  = 10     # save at the end to verify the save path works
SMOKE_LOG_FREQ   = 2
Path("outputs").mkdir(exist_ok=True)
smoke_log = "./outputs/pi05_smoke.log"

smoke_cmd = (
    f"rm -rf {SMOKE_OUTPUT_DIR} && uv run lerobot-train"
    f"{DATASET_FLAGS}"
    f"{POLICY_FLAGS}"
    f"{PEFT_FLAGS}"
    f"{COMMON_FLAGS}"
    f" --output_dir={SMOKE_OUTPUT_DIR}"
    f" --job_name=pi05_smoke"
    f" --steps={SMOKE_STEPS}"
    f" --save_freq={SMOKE_SAVE_FREQ}"
    f" --log_freq={SMOKE_LOG_FREQ}"
    f" 2>&1 | tee {smoke_log}"
)

print(f"Smoke test → {SMOKE_OUTPUT_DIR}")
print(f"Steps: {SMOKE_STEPS}, log every {SMOKE_LOG_FREQ}, save at step {SMOKE_SAVE_FREQ}")
print("Expected runtime: ~20 min compile warmup + a few steps ≈ 22–25 min total")
print(f"\nCommand:\n\n{smoke_cmd}\n")
# Out:
# Smoke test → ./outputs/pi05_smoke
# Steps: 10, log every 2, save at step 10
# Expected runtime: ~20 min compile warmup + a few steps ≈ 22–25 min total
#
# Command:
#
# rm -rf ./outputs/pi05_smoke && uv run lerobot-train --dataset.repo_id=ChrisCrossAppleSauce/so100_plant_pencil --dataset.root=./data/so100_plant_pencil --policy.type=pi05 --policy.pretrained_path=./models/pi05_base --policy.repo_id=ChrisCrossAppleSauce/pi05_so100_plant_pencil --policy.device=cuda --policy.dtype=bfloat16 --policy.compile_model=true --policy.compile_mode=reduce-overhead --policy.gradient_checkpointing=false --policy.freeze_vision_encoder=false --policy.train_expert_only=false --peft.method_type=LORA --peft.r=16 --batch_size=32 --seed=42 --eval_freq=0 --wandb.enable=true --wandb.project=pi05_so100_plant_pencil --output_dir=./outputs/pi05_smoke --job_name=pi05_smoke --steps=10 --save_freq=10 --log_freq=2 2>&1 | tee ./outputs/pi05_smoke.log

# %%
# Run smoke test (interrupt kernel to stop). tee handled by the shell pipe in smoke_cmd
import subprocess, sys

print(f"Starting smoke test... logs: {smoke_log}\n")
print("Note: torch.compile first step can take 5-20 min on a new GPU arch. Not a hang.\n")
process = subprocess.Popen(smoke_cmd, shell=True, executable="/bin/bash", stdout=sys.stdout, stderr=sys.stderr)
process.wait()
print(f"\nExit code: {process.returncode}")

# %%
# ── 4b. Full training command ────────────────────────────────
# Same flags as 4a — only steps/save/log differ.
from pathlib import Path
FULL_OUTPUT_DIR = "./outputs/pi05_so100_plant_pencil"
FULL_STEPS      = 5000
FULL_SAVE_FREQ  = 1000
FULL_LOG_FREQ   = 100
Path("outputs").mkdir(exist_ok=True)
full_log = "./outputs/pi05_so100_plant_pencil.log"

full_cmd = (
    f"rm -rf {FULL_OUTPUT_DIR} && uv run lerobot-train"
    f"{DATASET_FLAGS}"
    f"{POLICY_FLAGS}"
    f"{PEFT_FLAGS}"
    f"{COMMON_FLAGS}"
    f" --output_dir={FULL_OUTPUT_DIR}"
    f" --job_name=pi05_so100_plant_pencil"
    f" --steps={FULL_STEPS}"
    f" --save_freq={FULL_SAVE_FREQ}"
    f" --log_freq={FULL_LOG_FREQ}"
    f" 2>&1 | tee {full_log}"
)

print(f"Full training → {FULL_OUTPUT_DIR}")
print(f"Steps: {FULL_STEPS}, save every {FULL_SAVE_FREQ} ({FULL_STEPS // FULL_SAVE_FREQ} checkpoints)")
print(f"Expected wall-clock: ~{FULL_STEPS * 24 / 3600:.0f} hr (24s/step steady-state from smoke)")
print("Note: LoRA — checkpoints store adapter weights only (~5 MB), auto-pushed to HF Hub on each save.")
print(f"      `rm -rf` wipes any previous run in {FULL_OUTPUT_DIR}. Remove it if resuming.\n")
print(f"Command:\n\n{full_cmd}\n")
# Out:
# Full training → ./outputs/pi05_so100_plant_pencil
# Steps: 5000, save every 1000 (5 checkpoints)
# Expected wall-clock: ~33 hr (24s/step steady-state from smoke)
# Note: LoRA — checkpoints store adapter weights only (~5 MB), auto-pushed to HF Hub on each save.
#       `rm -rf` wipes any previous run in ./outputs/pi05_so100_plant_pencil. Remove it if resuming.
#
# Command:
#
# ...

# %%
# Run full training (interrupt kernel to stop). tee handled by the shell pipe in full_cmd.
# Resume: re-run with --resume=true appended (keep same --output_dir).
import subprocess, sys

print(f"Starting full training... logs: {full_log}\n")
process = subprocess.Popen(full_cmd, shell=True, executable="/bin/bash", stdout=sys.stdout, stderr=sys.stderr)
process.wait()
print(f"\nExit code: {process.returncode}")

# %% [markdown]
# ## 5. Train ACT Policy
#
# Trains ACT (Action Chunking Transformer) from scratch on your SO-100 dataset. ACT is an ~80M-param transformer + VAE with a ResNet18 ImageNet backbone — **~100× smaller than pi05**, so each step is much faster (sub-second vs ~24s). HuggingFace recommends ACT as the first model to try for small SO-100 datasets.
#
# **Why try ACT alongside pi05:**
# - No 7 GB pretrained checkpoint to download — ResNet18 weights auto-fetched on first run
# - Trains from scratch in a few hours instead of days
# - SOTA imitation-learning baseline (Zhao et al. 2023, *Learning Fine-Grained Bimanual Manipulation*)
#
# **Prereqs:**
# - `uv sync --extra dev` (ACT ships in base install — no `--extra pi` / `--extra peft` needed)
# - Dataset at `./data/so100_plant_pencil` (already present from section 3)
#
# **Recipe**: ACT paper defaults — ResNet18 IMAGENET1K_V1 backbone, `dim_model=512`, `n_heads=8`, `n_encoder_layers=4`, `n_decoder_layers=1`, `kl_weight=10.0`, VAE enabled, AdamW (lr=1e-5 for both transformer and backbone, weight_decay=1e-4). Only `chunk_size`/`n_action_steps` lowered from 100 → 50 (matches pi05 and typical SO-100 recipes). Image augmentation (ColorJitter/Sharpness) enabled.
#
# Run **5a** (smoke, ~1-3 min) to verify the pipeline, then **5b** (full run, 50k steps).

# %%
# ── Shared ACT training settings ──────────────────────────────
# Smoke and full runs use IDENTICAL flags — only steps/save/log differ.
ACT_DATASET_REPO_ID = "ChrisCrossAppleSauce/so100_plant_pencil"
ACT_DATASET_ROOT    = "./data/so100_plant_pencil"
ACT_OUTPUT_REPO_ID  = "ChrisCrossAppleSauce/act_so100_plant_pencil"
ACT_BATCH_SIZE      = 16
ACT_SEED            = 42
ACT_CHUNK_SIZE      = 50    # halves the default 100; matches pi05 and SO-100 convention

# Policy flags — ACT trains from scratch, no compile, no PEFT, no pretrained_path.
# ACTConfig does not expose dtype / gradient_checkpointing / freeze_vision_encoder;
# the ResNet18 ImageNet-pretrained backbone is auto-loaded by default.
ACT_POLICY_FLAGS = (
    f" --policy.type=act"
    f" --policy.repo_id={ACT_OUTPUT_REPO_ID}"
    f" --policy.device=cuda"
    f" --policy.push_to_hub=true"
    f" --policy.chunk_size={ACT_CHUNK_SIZE}"
    f" --policy.n_action_steps={ACT_CHUNK_SIZE}"   # must equal chunk_size
)

ACT_DATASET_FLAGS = (
    f" --dataset.repo_id={ACT_DATASET_REPO_ID}"
    f" --dataset.root={ACT_DATASET_ROOT}"
    f" --dataset.image_transforms.enable=true"   # HF-recommended ColorJitter/Sharpness aug
)

ACT_WANDB_PROJECT = "act_so100_plant_pencil"

ACT_COMMON_FLAGS = (
    f" --batch_size={ACT_BATCH_SIZE}"
    f" --seed={ACT_SEED}"
    f" --eval_freq=0"
    f" --num_workers=0"   # workers>0 segfaults on GB10: pyav isn't thread-safe, and torchcodec's ffmpeg libs exhaust glibc static-TLS after DataLoader fork. torchcodec single-threaded is still ~5x faster than pyav.
    f" --wandb.enable=true"
    f" --wandb.project={ACT_WANDB_PROJECT}"
)

print("ACT settings loaded.")
print(f"Dataset: {ACT_DATASET_REPO_ID}  (local: {ACT_DATASET_ROOT})")
print(f"Output:  {ACT_OUTPUT_REPO_ID}")
print(f"Batch:   {ACT_BATCH_SIZE}  |  seed: {ACT_SEED}  |  chunk_size: {ACT_CHUNK_SIZE}")
# Out:
# ACT settings loaded.
# Dataset: ChrisCrossAppleSauce/so100_plant_pencil  (local: ./data/so100_plant_pencil)
# Output:  ChrisCrossAppleSauce/act_so100_plant_pencil
# Batch:   16  |  seed: 42  |  chunk_size: 50

# %%
# ── 5a. ACT smoke test command ─────────────────────────────
# Same flags as 5b, just shorter — validates the full-run config end-to-end.
from pathlib import Path
ACT_SMOKE_OUTPUT_DIR = "./outputs/act_smoke"
ACT_SMOKE_STEPS      = 10
ACT_SMOKE_SAVE_FREQ  = 10     # save at the end to verify the save path works
ACT_SMOKE_LOG_FREQ   = 2
Path("outputs").mkdir(exist_ok=True)
act_smoke_log = "./outputs/act_smoke.log"

act_smoke_cmd = (
    f"rm -rf {ACT_SMOKE_OUTPUT_DIR} && uv run lerobot-train"
    f"{ACT_DATASET_FLAGS}"
    f"{ACT_POLICY_FLAGS}"
    f"{ACT_COMMON_FLAGS}"
    f" --output_dir={ACT_SMOKE_OUTPUT_DIR}"
    f" --job_name=act_smoke"
    f" --steps={ACT_SMOKE_STEPS}"
    f" --save_freq={ACT_SMOKE_SAVE_FREQ}"
    f" --log_freq={ACT_SMOKE_LOG_FREQ}"
    f" 2>&1 | tee {act_smoke_log}"
)

print(f"ACT smoke test → {ACT_SMOKE_OUTPUT_DIR}")
print(f"Steps: {ACT_SMOKE_STEPS}, log every {ACT_SMOKE_LOG_FREQ}, save at step {ACT_SMOKE_SAVE_FREQ}")
print("Expected runtime: ~1-3 min (no compile warmup; first step includes ResNet18 weight download if not cached)")
print(f"\nCommand:\n\n{act_smoke_cmd}\n")
# Out:
# ACT smoke test → ./outputs/act_smoke
# Steps: 10, log every 2, save at step 10
# Expected runtime: ~1-3 min (no compile warmup; first step includes ResNet18 weight download if not cached)
#
# Command:
#
# rm -rf ./outputs/act_smoke && uv run lerobot-train --dataset.repo_id=ChrisCrossAppleSauce/so100_plant_pencil --dataset.root=./data/so100_plant_pencil --dataset.image_transforms.enable=true --policy.type=act --policy.repo_id=ChrisCrossAppleSauce/act_so100_plant_pencil --policy.device=cuda --policy.push_to_hub=true --policy.chunk_size=50 --policy.n_action_steps=50 --batch_size=16 --seed=42 --eval_freq=0 --num_workers=0 --wandb.enable=true --wandb.project=act_so100_plant_pencil --output_dir=./outputs/act_smoke --job_name=act_smoke --steps=10 --save_freq=10 --log_freq=2 2>&1 | tee ./outputs/act_smoke.log

# %%
# Run smoke test (interrupt kernel to stop). tee handled by the shell pipe in act_smoke_cmd
import subprocess, sys

print(f"Starting ACT smoke test... logs: {act_smoke_log}\n")
print("Note: first step downloads ResNet18 ImageNet weights (~45 MB) if not cached.\n")
process = subprocess.Popen(act_smoke_cmd, shell=True, executable="/bin/bash", stdout=sys.stdout, stderr=sys.stderr)
process.wait()
print(f"\nExit code: {process.returncode}")

# %%
# ── 5b. Full ACT training command ────────────────────────────
# Same flags as 5a — only steps/save/log differ.
from pathlib import Path
ACT_FULL_OUTPUT_DIR = "./outputs/act_so100_plant_pencil"
ACT_FULL_STEPS      = 50000
ACT_FULL_SAVE_FREQ  = 10000
ACT_FULL_LOG_FREQ   = 100
Path("outputs").mkdir(exist_ok=True)
act_full_log = "./outputs/act_so100_plant_pencil.log"

act_full_cmd = (
    f"rm -rf {ACT_FULL_OUTPUT_DIR} && uv run lerobot-train"
    f"{ACT_DATASET_FLAGS}"
    f"{ACT_POLICY_FLAGS}"
    f"{ACT_COMMON_FLAGS}"
    f" --output_dir={ACT_FULL_OUTPUT_DIR}"
    f" --job_name=act_so100_plant_pencil"
    f" --steps={ACT_FULL_STEPS}"
    f" --save_freq={ACT_FULL_SAVE_FREQ}"
    f" --log_freq={ACT_FULL_LOG_FREQ}"
    f" 2>&1 | tee {act_full_log}"
)

print(f"Full ACT training → {ACT_FULL_OUTPUT_DIR}")
print(f"Steps: {ACT_FULL_STEPS}, save every {ACT_FULL_SAVE_FREQ} ({ACT_FULL_STEPS // ACT_FULL_SAVE_FREQ} checkpoints)")
print(f"Expected wall-clock: ~5-10 hr (ACT est. 0.4-0.7 s/step at batch={ACT_BATCH_SIZE} on GB10)")
print("Note: each checkpoint ~320 MB (full model fp32 + optimizer), auto-pushed to HF Hub.")
print(f"      `rm -rf` wipes any previous run in {ACT_FULL_OUTPUT_DIR}. Remove it if resuming.\n")
print(f"Command:\n\n{act_full_cmd}\n")
# Out:
# Full ACT training → ./outputs/act_so100_plant_pencil
# Steps: 50000, save every 10000 (5 checkpoints)
# Expected wall-clock: ~5-10 hr (ACT est. 0.4-0.7 s/step at batch=16 on GB10)
# Note: each checkpoint ~320 MB (full model fp32 + optimizer), auto-pushed to HF Hub.
#       `rm -rf` wipes any previous run in ./outputs/act_so100_plant_pencil. Remove it if resuming.
#
# Command:
#
# ...

# %%
# Run full training (interrupt kernel to stop). tee handled by the shell pipe in act_full_cmd.
# Resume: re-run with --resume=true appended (keep same --output_dir).
import subprocess, sys

print(f"Starting full ACT training... logs: {act_full_log}\n")
process = subprocess.Popen(act_full_cmd, shell=True, executable="/bin/bash", stdout=sys.stdout, stderr=sys.stderr)
process.wait()
print(f"\nExit code: {process.returncode}")

# %% [markdown]
# ## 6. Run Trained Policy
#
# Runs a trained policy on the real robot via `lerobot-record --policy.path=...`. The policy picks each action from observations; the rollout is saved as a local dataset you can replay or inspect afterwards.
#
# - Leader arm is still passed in so you can reset the scene between episodes (the policy drives the follower; the leader isn't read during episode execution).
# - `push_to_hub=false` — keep eval rollouts local.
# - No `--display_data=true` — camera feeds in rerun eat RAM on this laptop.

# %%
# ── Inference settings ────────────────────────────────────────────────
# Set to the HF repo (or local path) of the policy you want to roll out.
POLICY_PATH    = "ChrisCrossAppleSauce/act_so100_plant_pencil"
EVAL_REPO_ID   = "ChrisCrossAppleSauce/eval_act_so100_plant_pencil"   # local eval rollouts
EVAL_TASK      = "Plant the pencil into the pot"
EVAL_NUM_EPS   = 3
EVAL_EP_TIME_S = 30
EVAL_RESET_S   = 10
EVAL_FPS       = 30
EVAL_RESUME    = True   # append to existing eval dataset; set False (+ rm the dir) to start fresh

assert leader_port and follower_port, "Run cell 1 first! Ports not detected."

# Build cameras flag WITHOUT --display_data=true (laptop runs out of RAM with rerun feeds).
eval_cam_parts = []
if MODE in ("top_only", "top_wrist") and top_cam_index is not None:
    eval_cam_parts.append(f"top: {{type: opencv, index_or_path: {top_cam_index}, width: 640, height: 480, fps: 30}}")
if MODE in ("wrist_only", "top_wrist") and wrist_cam_index is not None:
    eval_cam_parts.append(f"wrist: {{type: opencv, index_or_path: {wrist_cam_index}, width: 640, height: 480, fps: 30}}")
eval_camera_flag = (
    f"--robot.cameras='{{ {', '.join(eval_cam_parts)} }}'" if eval_cam_parts else ""
)

eval_cmd = (
    f"lerobot-record"
    f" --robot.type=so100_follower --robot.port={follower_port} --robot.id=my_follower"
    f" --teleop.type=so100_leader --teleop.port={leader_port} --teleop.id=my_leader"
    f" {eval_camera_flag}"
    f" --policy.path={POLICY_PATH}"
    f" --dataset.repo_id={EVAL_REPO_ID}"
    f" --dataset.single_task='{EVAL_TASK}'"
    f" --dataset.num_episodes={EVAL_NUM_EPS}"
    f" --dataset.episode_time_s={EVAL_EP_TIME_S}"
    f" --dataset.reset_time_s={EVAL_RESET_S}"
    f" --dataset.fps={EVAL_FPS}"
    f" --dataset.push_to_hub=false"
    f" --resume={str(EVAL_RESUME).lower()}"
)

print(f"Policy:   {POLICY_PATH}")
print(f"Rollouts: {EVAL_NUM_EPS} × {EVAL_EP_TIME_S}s  →  {EVAL_REPO_ID}")
print(f"Task:     {EVAL_TASK}")
print(f"Resume:   {EVAL_RESUME}")
print(f"\nCommand:\n\n{eval_cmd}\n")
# Out:
# Policy:   ChrisCrossAppleSauce/act_so100_plant_pencil
# Rollouts: 3 × 30s  →  ChrisCrossAppleSauce/eval_act_so100_plant_pencil
# Task:     Plant the pencil into the pot
# Resume:   True
#
# Command:
#
# lerobot-record --robot.type=so100_follower --robot.port=/dev/ttyACM1 --robot.id=my_follower --teleop.type=so100_leader --teleop.port=/dev/ttyACM0 --teleop.id=my_leader --robot.cameras='{ top: {type: opencv, index_or_path: 0, width: 640, height: 480, fps: 30}, wrist: {type: opencv, index_or_path: 2, width: 640, height: 480, fps: 30} }' --policy.path=ChrisCrossAppleSauce/act_so100_plant_pencil --dataset.repo_id=ChrisCrossAppleSauce/eval_act_so100_plant_pencil --dataset.single_task='Plant the pencil into the pot' --dataset.num_episodes=3 --dataset.episode_time_s=30 --dataset.reset_time_s=10 --dataset.fps=30 --dataset.push_to_hub=false --resume=true

# %%
# Run policy on real robot (interrupt kernel to stop between episodes).
# `lerobot-record` prints keyboard hints at startup:
#   → arrow right = next episode, → arrow left = re-record previous, Esc = stop.
import subprocess, sys

print(f"Starting policy rollout... ({EVAL_NUM_EPS} episodes × {EVAL_EP_TIME_S}s)\n")
process = subprocess.Popen(eval_cmd, shell=True, executable="/bin/bash", stdout=sys.stdout, stderr=sys.stderr)
process.wait()
print(f"\nExit code: {process.returncode}")
